# %% [markdown]
# <a href="https://colab.research.google.com/github/CMBM1313/Data_Science.py/blob/main/D_S_Exercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from types import prepare_class
import random
def Cria():
  print("\n")
  ln=random.randint(2,10)
  lista = []
  for i in range(ln):
    lista.append(random.randint(1,26))
  return Traduz(lista)
def Traduz(lss):
  for i in range(len(lss)):
    if lss[i] == 1:
      lss[i] = 'a'
    elif lss[i] == 2:
      lss[i] = 'b'
    elif lss[i] == 3:
      lss[i] = 'c'
    elif lss[i] == 4:
      lss[i] = 'd'
    elif lss[i] == 5:
      lss[i] = 'e'
    elif lss[i] == 6:
      lss[i] = 'f'
    elif lss[i] == 7:
      lss[i] = 'g'
    elif lss[i] == 8:
      lss[i] = 'h'
    elif lss[i] == 9:
      lss[i] = 'i'
    elif lss[i] == 10:
      lss[i] = 'j'
    elif lss[i] == 11:
      lss[i] = 'k'
    elif lss[i] == 12:
      lss[i] = 'l'
    elif lss[i] == 13:
      lss[i] = 'm'
    elif lss[i] == 14:
      lss[i] = 'n'
    elif lss[i] == 15:
      lss[i] = 'o'
    elif lss[i] == 16:
      lss[i] = 'p'
    elif lss[i] == 17:
      lss[i] = 'q'
    elif lss[i] == 18:
      lss[i] = 'r'
    elif lss[i] == 19:
      lss[i] = 's'
    elif lss[i] == 20:
      lss[i] = 't'
    elif lss[i] == 21:
      lss[i] = 'u'
    elif lss[i] == 22:
      lss[i] = 'v'
    elif lss[i] == 22:
      lss[i] = 'w'
    elif lss[i] == 23:
      lss[i] = 'x'
    elif lss[i] == 25:
      lss[i] = 'y'
    elif lss[i] == 26:
      lss[i] = 'z'
  return Vira(lss)
def Vira(lts):
  for i in range(len(lts)):
    print(lts[i])
  return Cria()

palavra = ['p','h','y','t','o','n']
Vira(palavra)
