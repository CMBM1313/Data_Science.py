# %% [markdown]
# <a href="https://colab.research.google.com/github/CMBM1313/Data_Science.py/blob/main/D_S_Exercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import max, min
import random
def Gera():
  lst = random.randint(2,15)
  lista = []
  for i in range(lst):
    lista.append(random.randint(0,100))
  return Amplitude(lista)

def Amplitude(x):
  print(x, max(x)-min(x))
  return Gera()

Gera()
